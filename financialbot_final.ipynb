# %%
# !pip install spacy-sentence-bert
# !pip install scikit-learn
# !python -m spacy download en_core_web_md
# !pip install -U sentence-transformers
# !pip install nlpaug

# %%
import pandas as pd
import numpy as np
import spacy
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix

datasets_donwload_urllink = "https://drive.google.com/file/d/10dNvuX8Tk5xgoiCN3ohpyKzaFbYz-r8N/view?usp=drive_link"
file_id = '10dNvuX8Tk5xgoiCN3ohpyKzaFbYz-r8N'
user_interactions_url = f'https://drive.google.com/uc?id={file_id}'
topics_url = 'https://docs.google.com/spreadsheets/d/1FK1MxaY0U0KNxwXrAxbEfm4ylxWpY3o-QGiD5LpVK38/export?format=csv'

# %%
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# Helper Functions

# %%
def anonymize_names_v2(doc):
    text = doc.text
    replacements = {}
    name_id = 1

    for ent in doc.ents:
        if ent.label_ == "PERSON":
            replacements[(ent.start_char, ent.end_char)] = f"[NAME_{name_id}]"
            name_id += 1

    # Sort from last to first to avoid offset shifting
    new_text = text
    for (start, end), placeholder in sorted(replacements.items(), reverse=True):
        new_text = new_text[:start] + placeholder + new_text[end:]

    return new_text, replacements

def deanonymize_text(text, mapping):
    reverse_mapping = {v: k for k, v in mapping.items()}
    for anon, original in reverse_mapping.items():
        text = text.replace(anon, original)
    return text
    # revert back code
    # Add a column with the reverted text
    # df['deanonymized'] = df.apply(lambda row: deanonymize_text(row['anonymized'], row['name_mapping']), axis=1)

def text_topic_similarity(text, topic):
    doc1 = nlp(text)
    doc2 = nlp(topic)

    return doc1.similarity(doc2)

# %%
df = pd.read_csv(user_interactions_url)
df_topics = pd.read_csv(topics_url)

df.columns = ["rowid", "interaction", "label"]
df["anonymized_interaction"] = ''

# %% [markdown]
# ### Perform Anonymization

# %%
anonymized_results = []
replacement_maps = []

for doc in nlp.pipe(df['interaction'], batch_size=50):
    anonymized_text, mapping = anonymize_names_v2(doc)
    anonymized_results.append(anonymized_text)
    replacement_maps.append(mapping)

# Store results
df['anonymized_interaction'] = anonymized_results
df['name_mapping'] = replacement_maps

# %%
df_anonymized = df[["rowid", "anonymized_interaction", "label"]]

# %% [markdown]
# ### Perform Label evaluation and replacement

# %% [markdown]
# #### Before adding new label, evaluate original distribution and average confidence score with

# %%
df_anonymized = df_anonymized.replace({'label':
    {
        "AccountDetails":"Account Details",
        "Loan":"Loan and Credit Services","HomeLoan":"Loan and Credit Services","AutoLoan":"Loan and Credit Services",
        "DebitCard":"Debit/Credit Card","CreditCard":"Debit/Credit Card",
        "Offers":"Product Inquiries",
        "Grievances":"Complaints",
        "TechSupport":"Technical Support"
    }
})
df_anonymized["original_label_confidence"] = 0

# %%
from sentence_transformers import SentenceTransformer, util
from tqdm import tqdm
import torch
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# 1- Precompute text embeddings: text input
text_inputs = df_anonymized["anonymized_interaction"].tolist()
text_embeddings = model.encode(text_inputs, convert_to_tensor=True)

# %%
# 2- compute original label confidence with sentence transformer and cosine sim
old_labels = df_anonymized["label"].tolist()
old_label_embeddings = model.encode(old_labels, convert_to_tensor=True)
old_labels_confidence_score = []

for i in range(len(text_embeddings)):
    sim = util.cos_sim(text_embeddings[i], old_label_embeddings[i])
    old_labels_confidence_score.append(sim.item())  # Convert 1x1 tensor to float

df_anonymized['original_label_confidence'] = old_labels_confidence_score

# %%
# Label analysis on original datasets(anonymized) class distribution and average confidence per class
class_counts = df_anonymized['label'].value_counts()
old_avg = df_anonymized.groupby('label')['original_label_confidence'].mean()

# Create side-by-side bar charts
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
fig.suptitle("Class Distribution and Confidence Analysis", fontsize=16)

# Plot class counts (left)
class_counts.plot(kind='bar', ax=ax1, color='salmon')
ax1.set_title("Class counts per interaction")
ax1.set_ylabel("Count")
ax1.set_xticklabels(class_counts.index, rotation=45, ha='right')

# Plot average confidence (right)
old_avg.plot(kind='bar', ax=ax2, color='skyblue')
ax2.set_title("Average confidence score per label-interactions")
ax2.set_ylabel("Average Confidence")
ax2.set_xticklabels(old_avg.index, rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Add new label with their confidence score

# %% [markdown]
# #### Zero shot classification with new topics

# %%
df_anonymized["new_label"] = ""
df_anonymized["new_label_confidence"] = 0

# %%
# 2- Precompute topics embeddings: new topics and text input
# topics_embeddings = model.encode(topics, convert_to_tensor=True) --- Old method
topic_embeddings = {}
for topic, group in df_topics.groupby("topic"):
    enriched_texts = (
        "Topic: " + group["topic"] +
        ". Description: " + group["description"] +
        " Example: " + group["example"]
    ).tolist()

    embeddings = model.encode(enriched_texts, convert_to_tensor=True)
    avg_embedding = torch.mean(embeddings, dim=0)
    topic_embeddings[topic] = avg_embedding

# %%
# 4- compute new label confidence with sentence transformer and cosine sim using enricheds topics

# Step 1: Extract topic names and their averaged embeddings
topic_names = list(topic_embeddings.keys())  # e.g., ['Account Details', 'Product Inquiries', ...]
topic_avg_embeddings = torch.stack([topic_embeddings[topic] for topic in topic_names])  # shape: [num_topics, emb_dim]

# Step 2: Prepare to store results
predicted_topics = []
topics_confidence_scores = []

for text_emb in tqdm(text_embeddings):
    similarities = util.cos_sim(text_emb, topic_avg_embeddings)  # shape: [1, num_topics]
    best_idx = similarities.argmax().item()
    predicted_topics.append(topic_names[best_idx])
    topics_confidence_scores.append(similarities[0][best_idx].item())

# Step 3: save new labels and confidence score
df_anonymized["new_label"] = predicted_topics
df_anonymized["new_label_confidence"] = topics_confidence_scores
# Out:
# 100%|██████████| 1588/1588 [00:00<00:00, 10092.77it/s]

# %%
df_anonymized[["label", "original_label_confidence", "new_label", "new_label_confidence"]].head(2)
# Out:
#                       label  original_label_confidence  \
# 0  Loan and Credit Services                   0.504656
# 1  Loan and Credit Services                   0.432348
#
#                   new_label  new_label_confidence
# 0  Loan and Credit Services              0.418912
# 1  Loan and Credit Services              0.360671

# %% [markdown]
# ### Label distribution and comparison

# %%
#df_anonymized['new_label'].value_counts()
#df_anonymized['label'].value_counts()

# %%
new_class_counts = df_anonymized['new_label'].value_counts()
old_avg = df_anonymized.groupby('label')['original_label_confidence'].mean()
new_avg = df_anonymized.groupby('new_label')['new_label_confidence'].mean()

comparison_df = pd.DataFrame({
    'Old Label Confidence': old_avg,
    'New Label Confidence': new_avg
}).fillna(0)

# Create side-by-side bar charts
fig1, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
fig1.suptitle("updated dataset: class distribution and label confidence analysis", fontsize=16)

# Plot class counts (left)
new_class_counts.plot(kind='bar', ax=ax2, color='purple')
ax2.set_title("New class counts per interactions")
ax2.set_ylabel("Count")
ax2.set_xticklabels(new_class_counts.index, rotation=45, ha='right')

# Plot grouped bar chart (right)
import matplotlib.pyplot as plt
comparison_df.plot(kind='bar', ax=ax1, figsize=(12, 6), color=['skyblue', 'salmon'])
ax1.set_ylabel("Average Confidence")
ax1.set_title("Average Confidence per Class-interaction: old vs new labels")
ax1.set_xticklabels(comparison_df.index, rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Deal with label imbalance: apply oversampling with data augmentation

# %%
import nlpaug.augmenter.word as naw
import nltk
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
nltk.download('omw-1.4')  # For multilingual WordNet synonyms (optional but recommended)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
majority_classes = ["Debit/Credit Card Issues","Loan and Credit Services",]
minority_classes = [topic for topic in df_anonymized['new_label'].unique() if topic not in majority_classes]

# %%
df_anonymized = df_anonymized[["anonymized_interaction","new_label"]]
df_anonymized_minority = df_anonymized[df_anonymized['new_label'].isin(minority_classes)]
df_anonymized_majority = df_anonymized[~df_anonymized['new_label'].isin(minority_classes)]

# %%
df_anonymized_majority.head(3)
# Out:
#                               anonymized_interaction                 new_label
# 0  Hi [NAME_1], my name is [NAME_2]. What are the...  Loan and Credit Services
# 1  Hi [NAME_1], my name is [NAME_2], How long doe...  Loan and Credit Services
# 2  Hi [NAME_1], my name is [NAME_2],  What docume...  Loan and Credit Services

# %%
aug = naw.SynonymAug(aug_src='wordnet', model_path='en_core_web_md')

target = 450  # target_count_per_augmentation_perclass (mean or median of max class)
minority_counts = df_anonymized_minority['new_label'].value_counts()

repeats_per_class = {
    label: max((target - count) // count, 0)
    for label, count in minority_counts.items()
}

# %%
# del(df_augmented)
# del(df_balanced)
# del(augmented_texts)

# %%
augmented_texts = []
for label, group in df_anonymized_minority.groupby('new_label'):
    n_repeat = repeats_per_class[label]
    for _, row in group.iterrows():
        for _ in range(n_repeat):
            augmented_texts.append({
                "anonymized_interaction": aug.augment(row['anonymized_interaction']),
                "new_label": label
            })

# %%
# df_augmented = pd.DataFrame(augmented_texts)
# df_balanced = pd.concat([df_anonymized_majority, df_anonymized_minority, df_augmented], ignore_index=True)
#augmented_texts = [' '.join(tokens) for tokens in augmented_texts]
#df_augmented = pd.DataFrame({'anonymized_interaction': augmented_texts})

cleaned_augmented_texts = [
    {
        'anonymized_interaction': item['anonymized_interaction'][0] if isinstance(item['anonymized_interaction'], list) else item['anonymized_interaction'],
        'new_label': item['new_label']
    }
    for item in augmented_texts
]
df_augmented = pd.DataFrame(cleaned_augmented_texts)
df_balanced = pd.concat([df_anonymized_majority, df_anonymized_minority, df_augmented], ignore_index=True)
df_balanced = df_balanced.sample(frac=1).reset_index(drop=True)

# %%
# assert df_balanced['anonymized_interaction'].apply(lambda x: isinstance(x, str)).all()
# df_balanced.head(2)
# Out:
#                               anonymized_interaction     new_label
# 0  Howdy [NAME_1 ], my gens is [NAME_2 ]. Can I c...  Appointments
# 1  Hi [NAME_1 ], my name is [NAME_2 ], Hi, poster...   New Account

# %%
#df_balanced.sample(10)
augmented_texts
# Out:
# [{'anonymized_interaction': ["Hi [NAME_1 ], my epithet represent [NAME_2 ], Howdy, One ' m take care for a credit menu with a mobile app for easy account management. Perform you have any options like that? I ' m interested in obtaining some data. Could you wait on pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Aloha state [NAME_1 ], my name be [NAME_2 ], Aloha state, I ' m looking for a credit card with a nomadic app for easy account direction. Do you own any options like that? I ' m interested in obtaining some data. Could you assist maine?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name represent [NAME_2 ], Hi, I ' grand looking for a credit circuit board with a mobile app for easy write up management. Do you have any selection like that? I ' m interested in get some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], How do you do, I ' g looking for a deferred payment add in with a mobile app for easy explanation management. Do you hold any options like that? Atomic number 53 ' m interested in obtaining some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hi, Unity ' m looking for a reference plug in with a mobile app for easy news report direction. Do you have any options like that? I ' one thousand interested in obtaining some data. Could you aid me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hullo, I ' m looking for a credit lineup with a roving app for easy account management. Dress you have any options like that? I ' k interested in obtaining some data. Could you assist maine?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawaii [NAME_1 ], my name is [NAME_2 ], Hi, I ' m looking for a acknowledgment card with a mobile app for easy account direction. Do you have any options like that? Iodine ' m concerned in find some data. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["How do you do [NAME_1 ], my epithet is [NAME_2 ], Hi, what variety of customer support do you extend for credit card holders? I ' m interested in find some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawaii [NAME_1 ], my name is [NAME_2 ], Hi, what sort of customer support coiffure you offer up for credit card holders? I ' m concerned in obtaining some data. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name cost [NAME_2 ], Hawaii, what kind of client support do you offer for credit card holder? I ' m interested in obtaining some data point. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my figure be [NAME_2 ], Hi, what kind of client reinforcement make you volunteer for credit card holders? I ' yard interested in obtaining some data. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name be [NAME_2 ], Hi, what variety of customer funding do you offer for recognition card holders? I ' m concerned in obtaining some datum. Could you assist maine?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hi, what kind of customer backing do you extend for citation circuit board holder? I ' m interested in obtaining some data. Could you serve me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my epithet is [NAME_2 ], Hi, what sort of client support do you provide for credit card holder? 1 ' m interested in obtaining some datum. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my figure constitute [NAME_2 ], Hi! Pot I get a credit card if I have limited recognition history? I ' m interested in hold some information. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["How do you do [NAME_1 ], my public figure is [NAME_2 ], Hello! Keister I sustain a citation card if I own limited credit history? Ace ' m interested in obtaining some datum. Could you help me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name equal [NAME_2 ], How do you do! Can I get a credit entry menu if Ace have limited credit history? I ' meter concerned in obtaining some data. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawai'i [NAME_1 ], my gens is [NAME_2 ], Hello! Prat I get a credit rating card if I have bound credit history? I ' m interested in incur some data. Could you attend pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], How do you do! Fundament I start out a credit rating card if 1 have limited credit history? I ' m concerned in obtaining some information. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name exist [NAME_2 ], Howdy! John I get a credit card if I have throttle credit history? I ' g interested in obtaining some data point. Could you help me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my gens is [NAME_2 ], How do you do! Give the axe I get down a credit card if I stimulate limited credit history? I ' g interested in obtaining some information. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hi, I ' d alike to inquire about my credit rating card write up details. Can you provide me with information about my current residuum and available acknowledgment? Would information technology be possible for you to share some insights?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my epithet is [NAME_2 ], Hi, 1 ' vitamin d like to inquire about my mention card account inside information. Can you provide me with information about my current balance and available credit? Would information technology be potential for you to share some insights?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hi, I ' vitamin d like to inquire about my credit circuit board account detail. Backside you provide maine with information about my current balance and available credit? Would it be possible for you to share some insights?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hawaii, I ' d similar to inquire about my credit card account point. Can you offer me with information about my current correspondence and available credit? Would it be possible for you to share some insights?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hullo [NAME_1 ], my name represent [NAME_2 ], Hi, 1 ' d like to inquire about my reference card explanation detail. Can you provide me with information about my current balance and available credit? Would it be possible for you to share some insights?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawaii [NAME_1 ], my name is [NAME_2 ], Hi, I ' d like to inquire astir my credit card account details. Can you provide maine with information about my current balance and uncommitted credit? Would it be potential for you to part some insight?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Howdy [NAME_1 ], my name is [NAME_2 ], Hi, I ' ergocalciferol like to inquire about my credit placard account details. Tin you provide me with information about my current balance and uncommitted deferred payment? Would it personify possible for you to share some insight?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], I call for to update my contact information connect with my acknowledgment wit score. How lav I do that? Can you furnish me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure is [NAME_2 ], I take to update my contact information associated with my credit card account. How can Iodin do that? Hindquarters you offer pine tree state with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet cost [NAME_2 ], I need to update my contact selective information tie in with my credit poster account. How can I do that? Derriere you provide me with some selective information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Ace require to update my contact information associated with my credit rating card accounting. How can 1 serve that? Backside you provide me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need to update my contact information relate with my credit card account. How canful One do that? Can you render me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet constitute [NAME_2 ], I necessitate to update my contact lens information associated with my citation card account. How can I do that? Can you provide me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my figure be [NAME_2 ], I need to update my contact data associated with my credit card account. How can 1 do that? Buns you allow me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my figure is [NAME_2 ], I want to know the interest rate on my credit circuit board. Can you provide pine tree state with that information? Might you constitute able bodied to render me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet is [NAME_2 ], I want to know the interest pace on my credit card. Can you supply me with that information? Mightiness you be able bodied to issue me with the necessary data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure is [NAME_2 ], I want to know the interest charge per unit on my credit card. Can you allow me with that information? Might you comprise able to furnish me with the necessary data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], I want to recognise the interest rate on my credit card. Buns you provide me with that information? Might you be able to provide maine with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my figure is [NAME_2 ], I want to know the stake rate on my deferred payment card. Terminate you furnish me with that info? Might you be able to supply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I want to cognise the interest rate on my credit card. Can you provide me with that information? Might you embody able bodied to supply me with the necessary data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name embody [NAME_2 ], I want to fuck the pursuit rate on my credit card. Can you provide me with that information? Might you be able to supply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need assistance with updating my billing name and address for my credit card. How can I do that? Is at that place a chance I could obtain some particular proposition from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Howdy [NAME_1 ], my name is [NAME_2 ], I necessitate assistance with updating my billing address for my credit card. How can 1 do that? Is in that respect a chance One could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], I need assistance with updating my charge address for my credit card. How can I set that? Be there a chance Unity could receive some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], I require assistance with updating my billing address for my acknowledgment card. How ass I do that? Is there a chance Ace could obtain some particular from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], Iodin require assistance with updating my billing reference for my credit card. How can I do that? Is in that location a luck Iodin could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I ask assistance with update my billing address for my deferred payment card. How can I do that? Be there a chance 1 could get some particular from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I require assistance with updating my charge computer address for my credit card. How hindquarters 1 dress that? Be there a fortune I could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my name is [NAME_2 ], 1 want to lie with the grace period on my mention card. Can you provide me with that selective information? Could you furnish maine with relevant detail?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my gens be [NAME_2 ], I want to know the grace of god time period on my credit card. Can you supply me with that information? Could you furnish pine tree state with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], Single desire to know the grace period on my credit entry card. Tooshie you supply me with that entropy? Could you furnish me with relevant point?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my figure is [NAME_2 ], Single want to bang the seemliness period on my credit card. Can you furnish pine tree state with that information? Could you furnish me with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I want to know the grace period on my credit add in. Can you provide pine tree state with that information? Could you furnish me with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure personify [NAME_2 ], Ace want to know the grace period on my credit card. Can you cater maine with that data? Could you furnish me with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my name is [NAME_2 ], I require to know the grace full point on my recognition card. Buttocks you put up me with that information? Could you supply me with relevant detail?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Ace require to know the credit card rewards programme tier and benefits. Can you provide me with that information? Power you make up capable to supply me with the necessary entropy?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet is [NAME_2 ], I need to know the credit card rewards programme tiers and benefit. Can you provide pine tree state with that information? Mightiness you be able to supply maine with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I want to know the reference add in rewards programme tiers and benefit. Can you provide me with that information? Might you live able to supply maine with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my name is [NAME_2 ], I want to know the credit card rewards program tier and benefits. Can you offer me with that information? Mightiness you constitute able to add pine tree state with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my name is [NAME_2 ], I desire to have a go at it the credit card rewards program tier and benefit. Can you provide me with that information? Might you be able to ply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], One want to know the citation menu rewards program level and benefit. Can you leave me with that information? Might you be able to supply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Howdy [NAME_1 ], my name is [NAME_2 ], Iodin desire to lie with the credit batting order rewards program tiers and benefit. Can you provide pine tree state with that information? Might you follow able to supply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ]. I want assistance with setting up a credit posting balance alarum. How can I cause that? Tooshie you provide maine with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ]. I ask assistance with setting up a credit card libra the balance alert. How can Ace practice that? Displace you provide maine with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ]. One need assistance with arrange upwardly a credit card correspondence alert. How can I do that? Bathroom you provide me with some data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ]. I need assistance with setting up a credit card balance alarm. How bathroom Unity do that? Give the sack you provide pine tree state with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Howdy [NAME_1 ], my public figure is [NAME_2 ]. I require assistance with setting up a credit card rest alerting. How can I do that? Tin can you provide me with some data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my name is [NAME_2 ]. Single need assistance with place up a credit card equilibrium alert. How can I do that? Can you supply maine with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my name be [NAME_2 ]. I take assistance with coiffure up a deferred payment card balance alert. How can I do that? Tail end you provide pine tree state with some entropy?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawaii [NAME_1 ], my name is [NAME_2 ], I desire to know the credit wit annual percentage charge per unit (APR ). Can you provide me with that selective information? I ' megabyte interested in obtaining some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my gens is [NAME_2 ], I require to fuck the credit card annual percentage rate (april ). Can you provide me with that information? I ' m interested in obtaining some data. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my gens is [NAME_2 ], Iodine want to know the credit batting order annual percentage pace (APR ). Can you provide pine tree state with that information? Ace ' m interested in obtaining some data. Could you attend me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my gens is [NAME_2 ], Atomic number 53 want to know the credit card one year per centum rate (APR ). Can you provide me with that information? I ' m interested in prevail some data point. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["How do you do [NAME_1 ], my figure be [NAME_2 ], I need to get laid the quotation card yearly percentage rate (APR ). Can you provide me with that information? One ' molar concentration interested in obtaining some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], I want to make love the credit board annual percentage rate (april ). Can you provide maine with that entropy? 1 ' m interested in prevail some information. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hello [NAME_1 ], my name be [NAME_2 ], I need to know the credit card yearly portion charge per unit (APR ). Can you provide me with that information? 1 ' molarity interested in obtaining some data. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name constitute [NAME_2 ], I desire to know the credit card balance transfer eligibility criteria. Bathroom you provide me with that data? Might you be able bodied to supply pine tree state with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I want to make love the credit board residue transfer eligibility criteria. Can you provide pine tree state with that selective information? Power you be capable to supply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], 1 need to know the reference card libra transportation eligibility criteria. Can you provide me with that information? Mightiness you be capable to supply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawai'i [NAME_1 ], my name is [NAME_2 ], I want to do it the credit card balance transfer of training eligibility criteria. Can you supply me with that information? Mightiness you be able to supply me with the necessary selective information?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my name be [NAME_2 ], I want to know the recognition posting balance transfer eligibility criteria. Can you provide me with that information? Might you be capable to ply me with the necessary data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens be [NAME_2 ], One want to know the credit card balance transference eligibility criteria. Can you allow for me with that data? Might you be able to supply me with the necessary info?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure equal [NAME_2 ], Ane want to know the credit poster counterbalance transfer eligibility criteria. Can buoy you provide me with that information? Power you be able to supply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hello [NAME_1 ], my figure is [NAME_2 ], I want assistance with go under upwardly a recognition card statement notification. How commode I suffice that? Would it be possible for you to portion some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my gens is [NAME_2 ], 1 need assistance with setting up a credit placard statement notification. How toilet I do that? Would it be possible for you to share some penetration?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need assistance with arrange upwards a credit board statement notification. How can I do that? Would it constitute possible for you to share some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], One call for assistance with setting improving a credit wag statement notification. How bum I do that? Would information technology be possible for you to share some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my figure be [NAME_2 ], I need assistance with setting upwardly a credit card statement notification. How canful I do that? Would it constitute potential for you to part some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name live [NAME_2 ], I require assistance with setting up a credit entry card statement notification. How lav Ane do that? Would it equal possible for you to share some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure is [NAME_2 ], I need assistance with setting upward a recognition card statement notification. How can I do that? Would information technology equal possible for you to share some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens be [NAME_2 ]. How do you do, I would like to know the current balance on my debit card history. Is there a chance 1 could obtain some particular from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ]. Hello, I would like to recognize the current balance on my debit entry card news report. Is there a chance Ane could hold some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ]. Hello, Ace would care to know the current balance on my debit wit account. Be there a chance 1 could hold some detail from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my gens embody [NAME_2 ]. How do you do, I would wish to know the current balance on my debit board story. Is there a chance I could obtain some particular from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my name is [NAME_2 ]. Hello, I would like to know the current counterbalance on my debit entry add in account. Is there a chance I could hold some item from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawai'i [NAME_1 ], my epithet be [NAME_2 ]. Hello, I would like to know the current balance on my debit card story. Personify there a chance I could receive some particulars from you?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ]. Hello, Unity would like to know the current balance on my debit poster chronicle. Is there a luck Ane could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ]. Hello, Atomic number 53 would like to know the current balance on my debit entry card account. Is thither a chance I could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my gens represent [NAME_2 ]. Hello, Ace would like to experience the current balance on my debit card account. Is there a chance I could prevail some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name constitute [NAME_2 ]. Hello, I would like to know the current residual on my debit card report. Cost in that location a chance I could obtain some particular from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ]. Hello, Iodine would wish to jazz the current balance on my debit calling card account. Is there a chance I could find some particular from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Howdy [NAME_1 ], my name is [NAME_2 ]. Hello, I would like to know the current balance on my debit card account statement. Is at that place a chance Iodine could hold some particular from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Howdy [NAME_1 ], my name be [NAME_2 ]. Hi, I would like to know the current balance on my debit entry card account. Is thither a hazard I could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my figure is [NAME_2 ]. Hello, Atomic number 53 would like to recognise the current balance on my debit carte story. Is there a chance I could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hullo, I would like to jazz the current proportionality on my debit poster account statement. I ' m interested in obtaining some datum. Could you aid me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Aloha state [NAME_1 ], my epithet comprise [NAME_2 ], Hello, I would care to know the current balance on my debit card account. Iodine ' m concerned in obtaining some data. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my epithet is [NAME_2 ], Hello, I would care to know the current symmetricalness on my debit card account. One ' m interested in obtain some data. Could you attend me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my gens be [NAME_2 ], Hello, I would like to know the current balance on my debit card account. I ' m interested in obtaining some datum. Could you attend to pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], How do you do, I would wish to know the current balance on my debit entry card account. Ane ' m concerned in obtaining some information. Could you aid maine?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hello, I would like to know the current balance on my debit plug in account. Unity ' yard interested in obtaining some information. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawaii [NAME_1 ], my name is [NAME_2 ], How do you do, I would like to know the current correspondence on my debit calling card accounting. I ' m interested in obtaining some information. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Aloha state [NAME_1 ], my public figure be [NAME_2 ], Hullo, I would like to recognise the current balance on my debit card account. I ' m concerned in obtaining some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name be [NAME_2 ], Hi, 1 would like to know the current balance on my debit entry card account. I ' k interested in obtaining some data point. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name be [NAME_2 ], Hi, I would wish to know the current balance on my debit entry card account. I ' m interested in hold some data point. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Aloha state [NAME_1 ], my name be [NAME_2 ], Hello, Single would like to get laid the current balance on my debit circuit card chronicle. I ' mb interested in prevail some datum. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Hello, 1 would like to bed the current symmetry on my debit board invoice. I ' grand interested in obtaining some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], How do you do, Atomic number 53 would like to know the current libra on my debit card chronicle. I ' m interested in obtaining some data point. Could you assist maine?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my epithet is [NAME_2 ], Hello, Iodine would like to cognise the current equilibrium on my debit card account. I ' yard interested in obtaining some data point. Could you wait on me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet embody [NAME_2 ], Hello, 1 would like to know the current balance on my debit entry circuit card history. Can you provide pine tree state with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure is [NAME_2 ], Hullo, I would care to know the current balance on my debit card account. Can you cater me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Hello, I would wish to know the current counterbalance on my debit entry card account. Can you furnish pine tree state with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my name cost [NAME_2 ], Hello, I would care to make love the current libra the balance on my debit card account. Can you ply maine with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my epithet is [NAME_2 ], Hi, Iodine would like to recognise the current balance on my debit entry card account. Can you provide me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my figure exist [NAME_2 ], Hullo, I would wish to know the current balance on my debit entry card account. Can you provide maine with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my figure is [NAME_2 ], Hello, I would like to know the current balance on my debit entry card account. Tin you provide me with some info?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my name is [NAME_2 ], Howdy, I would like to cognize the current balance on my debit lineup report. Can you render me with some selective information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ], Hello, One would care to know the current balance on my debit card account. Bottom you provide pine tree state with some data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my name is [NAME_2 ], Howdy, I would like to know the current remainder on my debit entry visiting card explanation. Can you allow me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my name be [NAME_2 ], Hi, I would like to know the current balance on my debit bill report. Can you allow for me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], Hullo, I would wish to know the current balance on my debit card bill. Stool you put up me with some selective information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawai'i [NAME_1 ], my name be [NAME_2 ], How do you do, One would like to know the current balance on my debit card account. Can you provide me with some data?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], Hi, 1 would care to bed the current counterweight on my debit identity card account. Can you provide me with some entropy?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Hello, I would wish to know the current libra on my debit circuit card story. Could you supply pine tree state with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my public figure is [NAME_2 ], Hullo, Single would like to know the current balance on my debit card account. Could you supply me with relevant point?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my epithet be [NAME_2 ], Hello, 1 would like to know the current balance on my debit entry card account. Could you furnish me with relevant inside information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name represent [NAME_2 ], Hello, I would wish to know the current balance on my debit card account. Could you furnish maine with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my name is [NAME_2 ], Hello, 1 would like to have a go at it the current equalizer on my debit card account. Could you furnish maine with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Hello, I would wish to know the current rest on my debit entry wag account. Could you supply me with relevant detail?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], Hello, I would like to know the current counterweight on my debit entry card account. Could you furnish me with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Hello, 1 would care to bang the current symmetricalness on my debit card bill. Could you provide pine tree state with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], How do you do, Atomic number 53 would like to know the current libra on my debit add in business relationship. Could you furnish me with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ], Hello, 1 would wish to know the current balance on my debit card account. Could you supply me with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ], Hello, I would like to bed the current balance on my debit entry card story. Could you render me with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure is [NAME_2 ], Hi, I would like to have it away the current counterbalance on my debit card accounting. Could you furnish pine tree state with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hello [NAME_1 ], my name is [NAME_2 ], Howdy, I would like to roll in the hay the current balance on my debit card account. Could you supply me with relevant details?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my name be [NAME_2 ], Hello, One would like to cognize the current equaliser on my debit card account. Could you furnish maine with relevant contingent?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my gens be [NAME_2 ]. Hello, I would like to know the current symmetry on my debit card account. Would information technology cost possible for you to share some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ]. Hello, I would care to jazz the current balance on my debit add in accounting. Would information technology be potential for you to share some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my name is [NAME_2 ]. Hello, I would like to know the current equalizer on my debit posting account. Would information technology make up possible for you to share some perceptiveness?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ]. Hello, Atomic number 53 would care to screw the current libra on my debit entry card account. Would it be potential for you to share some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet is [NAME_2 ]. Hello, Iodin would care to know the current balance on my debit notice news report. Would it personify possible for you to share some perceptivity?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ]. Hello, I would like to know the current counterbalance on my debit entry board account. Would it be possible for you to share some insights?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my name be [NAME_2 ]. Hello, I would care to know the current balance on my debit card account. Would information technology be possible for you to share some sixth sense?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my name is [NAME_2 ], Hello, I would like to know the current balance on my debit entry card account. Might you be able bodied to ply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], How do you do, I would care to know the current balance on my debit notice account. Power you personify able to cater me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawai'i [NAME_1 ], my name is [NAME_2 ], Hello, I would like to know the current balance on my debit card account. Power you personify capable to render me with the necessary information?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Hullo, One would like to know the current counterpoise on my debit entry batting order account. Might you follow able to supply maine with the necessary data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name personify [NAME_2 ], Hello, Unity would like to know the current balance on my debit entry card story. Might you be able to supply pine tree state with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name constitute [NAME_2 ], Hello, I would like to live the current balance on my debit entry board account. Power you be able to supply me with the necessary information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], Hullo, Atomic number 53 would like to know the current balance on my debit card account. Might you cost able to provide me with the necessary selective information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my gens be [NAME_2 ], Hello, I would care to know the current balance on my debit card account. Is there a chance I could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ], Hello, 1 would wish to bed the current balance on my debit entry card account. Is there a probability Ane could get some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my figure is [NAME_2 ], Hello, I would like to know the current equipoise on my debit card account. Is there a probability I could obtain some detail from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Howdy [NAME_1 ], my epithet is [NAME_2 ], Hello, I would like to know the current balance on my debit entry card invoice. Cost in that location a chance Ane could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Hullo, I would like to know the current balance on my debit entry card chronicle. Is in that location a chance I could obtain some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my name is [NAME_2 ], How do you do, Atomic number 53 would wish to bang the current balance on my debit card account. Is there a chance I could hold some particulars from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], Hullo, I would like to screw the current residual on my debit card account. Is there a chance Iodine could get some specific from you?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name cost [NAME_2 ], Hello, I would care to know the current balance wheel on my debit card account. Ane ' m interested in obtaining some data. Could you help me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my figure is [NAME_2 ], How do you do, 1 would like to have it away the current balance on my debit card account statement. Iodin ' m interested in obtaining some datum. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], Howdy, Single would like to know the current balance on my debit entry card account. I ' one thousand interested in prevail some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name be [NAME_2 ], Hullo, I would like to know the current balance on my debit entry card account. I ' m interested in obtaining some information. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hawaii [NAME_1 ], my name is [NAME_2 ], Hello, One would like to know the current balance on my debit card account. I ' mib interested in hold some data. Could you assist pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Aloha state [NAME_1 ], my name personify [NAME_2 ], Hello, I would care to know the current balance on my debit calling card account. One ' m interested in obtaining some data. Could you assist me?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ["Hi [NAME_1 ], my name is [NAME_2 ], How do you do, I would like to have it off the current balance on my debit entry lineup account. I ' m interested in obtaining some data. Could you aid pine tree state?"],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my name is [NAME_2 ]. Hello, One would like to know the current rest on my debit entry menu account. Can you furnish me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ]. Hello, Iodin would like to know the current balance on my debit entry carte du jour account. Can you supply maine with some info?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name constitute [NAME_2 ]. Hello, I would care to fuck the current balance on my debit card account. Can you provide me with some data?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name follow [NAME_2 ]. Hullo, I would like to have it away the current symmetry on my debit wag bill. Can you allow me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet is [NAME_2 ]. Hello, I would care to roll in the hay the current balance on my debit entry card story. Can you cater me with some information?'],
#   'new_label': 'Account Details'},
#  {'anonymized_interaction': ['Hello [NAME_1 ], my epithet is [NAME_2 ]. Hello, I would like to make out the current balance on my debit plug in account. Can you provide maine with some information?'],
#   'new_label': 'Account Details'},
# ...
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my gens is [NAME_2 ], Single need assistance with setting up a credit card due date admonisher. How keister I do that? Would it be potential for you to portion some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need assistance with setting upwards a credit card due engagement reminder. How can I do that? Would information technology cost possible for you to share some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], 1 need assistance with set up a acknowledgment card due date reminder. How can One exercise that? Would information technology be potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my gens live [NAME_2 ], I need assistance with setting up a credit card due date reminder. How can I do that? Would information technology equal potential for you to portion some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Howdy [NAME_1 ], my name is [NAME_2 ], Iodine need assistance with localise upward a credit card due date admonisher. How can I do that? Would information technology follow possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Ace want assistance with setting astir a credit card referable date reminder. How can Iodin do that? Would it be potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ], I involve assistance with setting up a credit rating card due date reminder. How can Atomic number 53 act that? Would it cost potential for you to plowshare some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name follow [NAME_2 ], Unity need assistance with setting improving a credit card due date reminder. How can I practice that? Would it equal possible for you to part some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I postulate assistance with setting up a credit card due day of the month monitor. How can I arrange that? Would information technology be possible for you to portion some perceptivity?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my name is [NAME_2 ], I need assistance with setting up a quotation card referable date reminder. How can I do that? Would it be possible for you to share some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my name be [NAME_2 ], I need assistance with setting up a credit card imputable date reminder. How can I do that? Would information technology constitute potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Ane need assistance with setting upward a credit rating card imputable escort monitor. How can I do that? Would it be possible for you to plowshare some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Unity need assistance with put upward a credit card due date reminder. How can I do that? Would it be potential for you to part some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my name is [NAME_2 ], I need assistance with gear up up a credit placard referable date monitor. How can I do that? Would it be potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my figure represent [NAME_2 ], Iodine need assistance with setting up a course credit card referable date reminder. How can I do that? Would it make up possible for you to share some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name cost [NAME_2 ], 1 need assistance with plant up a credit card due date reminder. How can I do that? Would information technology follow potential for you to part some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need assistance with setting upwards a credit card due date admonisher. How can Iodin do that? Would it equal potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet is [NAME_2 ], I need assistance with setting up a credit rating poster due date reminder. How can Single do that? Would it comprise possible for you to portion some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hello [NAME_1 ], my name comprise [NAME_2 ], 1 require assistance with correct up a credit card due date reminder. How can I do that? Would it be possible for you to part some perceptiveness?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ], I involve assistance with setting upwards a credit card imputable day of the month reminder. How can I do that? Would information technology be possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my name is [NAME_2 ], I need assistance with setting up a credit lineup due date admonisher. How can I set that? Would it cost possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I necessitate assistance with coiffe up a credit notice due engagement reminder. How toilet I do that? Would it be possible for you to parcel some brainstorm?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hello [NAME_1 ], my name is [NAME_2 ], I need assistance with sic astir a credit card due engagement reminder. How can Ace do that? Would information technology represent possible for you to percentage some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my figure is [NAME_2 ], I need assistance with setting upward a credit circuit board due date reminder. How displace Atomic number 53 do that? Would it be possible for you to share some sixth sense?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name constitute [NAME_2 ], I ask assistance with setting upward a acknowledgment card due escort reminder. How tin can I do that? Would information technology be possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Single demand assistance with set up a credit card due date admonisher. How can I cause that? Would it be possible for you to share some brainstorm?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hello [NAME_1 ], my name is [NAME_2 ], I need assistance with setting upward a credit card due date monitor. How can I cause that? Would information technology cost possible for you to plowshare some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], I need assistance with countersink up a quotation card referable appointment admonisher. How can I arrange that? Would it be potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hello [NAME_1 ], my name is [NAME_2 ], I need assistance with setting up a citation identity card ascribable date admonisher. How can I do that? Would it represent potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet is [NAME_2 ], Iodin need assistance with setting up a deferred payment scorecard due date reminder. How rear I coiffure that? Would it be potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need assistance with setting upward a credit card due date admonisher. How tin can I do that? Would information technology constitute possible for you to parcel some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name constitute [NAME_2 ], 1 need assistance with setting up a course credit card due engagement reminder. How give the sack Iodin do that? Would it be possible for you to share some perceptivity?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I necessitate assistance with determine up a acknowledgment card due escort reminder. How tin I do that? Would it be possible for you to share some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my name is [NAME_2 ], I need assistance with sic up a credit card ascribable escort reminder. How can One do that? Would it be potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet is [NAME_2 ], I need assistance with set up a credit card ascribable date reminder. How dismiss Iodine do that? Would information technology make up possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Aloha state [NAME_1 ], my gens is [NAME_2 ], I need assistance with setting upwards a credit card ascribable date admonisher. How can Atomic number 53 make out that? Would it be possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my name is [NAME_2 ], Unity need assistance with setting up a credit card due escort reminder. How toilet I do that? Would information technology be possible for you to plowshare some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need assistance with coif up a credit card due day of the month admonisher. How bathroom 1 do that? Would information technology be possible for you to ploughshare some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure is [NAME_2 ], I need assistance with set up a credit card referable engagement reminder. How force out I do that? Would it represent possible for you to share some sixth sense?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I ask assistance with ready up a credit card imputable date admonisher. How can I do that? Would it be possible for you to percentage some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my public figure be [NAME_2 ], I require assistance with setting up a credit lineup due date reminder. How displace I do that? Would it be possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my gens is [NAME_2 ], Atomic number 53 need assistance with setting up a credit card referable date reminder. How can I make that? Would it be possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hawaii [NAME_1 ], my name is [NAME_2 ], 1 want assistance with setting up a credit card due appointment reminder. How can I manage that? Would it be potential for you to portion some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet comprise [NAME_2 ], I need assistance with setting up a recognition menu ascribable date reminder. How can I do that? Would it be possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need assistance with setting up a credit entry card referable date reminder. How throne Atomic number 53 do that? Would information technology exist possible for you to portion some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my epithet is [NAME_2 ], Iodine need assistance with setting up a reference card due date admonisher. How fanny I serve that? Would it be potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name constitute [NAME_2 ], I need assistance with setting upwards a credit card due escort monitor. How tin I do that? Would it be potential for you to share some perceptivity?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], Atomic number 53 need assistance with setting upwards a credit card due particular date reminder. How tush Ace coif that? Would it be potential for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my figure is [NAME_2 ], I need assistance with setting upward a credit card ascribable date admonisher. How can One make that? Would information technology be possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name personify [NAME_2 ], I need assistance with set up a quotation card imputable date reminder. How derriere Iodin do that? Would it comprise possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], 1 ask assistance with set up a credit menu due date reminder. How can Iodin do that? Would it be possible for you to share some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['How do you do [NAME_1 ], my figure constitute [NAME_2 ], 1 need assistance with setting up a credit card due date reminder. How can I do that? Would information technology cost potential for you to part some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ["Hawai'i [NAME_1 ], my public figure is [NAME_2 ], I need assistance with setting up a credit card referable date admonisher. How can I do that? Would it be potential for you to share some brainwave?"],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Howdy [NAME_1 ], my name is [NAME_2 ], Iodin take assistance with setting up a citation card due date admonisher. How can Iodine do that? Would it be potential for you to part some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name is [NAME_2 ], I need assistance with plant up a mention board ascribable date reminder. How can I do that? Would it be possible for you to part some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my public figure represent [NAME_2 ], Atomic number 53 demand assistance with setting up a credit placard due date reminder. How can I suffice that? Would information technology be possible for you to share some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hi [NAME_1 ], my name be [NAME_2 ], I need assistance with setting astir a acknowledgment card due date reminder. How fanny I do that? Would it be potential for you to percentage some insights?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hullo [NAME_1 ], my name is [NAME_2 ], I take assistance with setting upwards a credit card ascribable date reminder. How commode I cause that? Would information technology be possible for you to share some insight?'],
#   'new_label': 'Appointments'},
#  {'anonymized_interaction': ['Hello [NAME_1 ], my name is [NAME_2 ], I need assistance with setting up a credit card due day of the month monitor. How can Unity perform that? Would information technology be potential for you to percentage some insights?'],
#   'new_label': 'Appointments'},
#  ...]

# %%
balanced_class_counts = df_balanced['new_label'].value_counts()

# Plot the bar chart
plt.figure(figsize=(10, 6))
balanced_class_counts.plot(kind='bar', color='mediumseagreen')
plt.title("Balanced Class Counts (new_label)")
plt.xlabel("Class")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Model Evaluation

# %%
import spacy_sentence_bert
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Load model and vectorize
nlpwrapper = spacy_sentence_bert.load_model('en_stsb_distilbert_base')
df_balanced['vector'] = df_balanced['anonymized_interaction'].apply(lambda x: nlpwrapper(x).vector)

# %%
# Split data
X = df_balanced['vector'].tolist()
y = df_balanced['new_label'].tolist()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Define models
models = {
    "SVC (RBF Kernel)": SVC(),
    "LinearSVC": LinearSVC(),
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "RandomForest": RandomForestClassifier(),
    "HistGradientBoosting": HistGradientBoostingClassifier()
}

# Train and evaluate each model
for name, model in models.items():
    print(f"\nTraining model: {name}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"Classification report for {name}:\n")
    print(classification_report(y_test, y_pred))
# Out:
# Training model: SVC (RBF Kernel)
# Classification report for SVC (RBF Kernel):
#
#                              precision    recall  f1-score   support
#
#             Account Details       0.79      0.81      0.80       143
#           Account Inquiries       0.85      0.90      0.87       142
#                Appointments       0.91      0.99      0.95       145
#                  Complaints       1.00      1.00      1.00       159
#           Debit/Credit Card       0.81      0.89      0.85       187
#            Fees and Charges       0.87      0.81      0.84       155
# Fraud and Security Concerns       0.97      0.94      0.96       151
#    General Financial Advice       0.98      1.00      0.99       157
#    Loan and Credit Services       0.83      0.90      0.86       137
#                 New Account       0.99      0.99      0.99       139
#           Product Inquiries       0.90      0.80      0.85       143
#                       Sales       0.80      0.80      0.80       127
#           Technical Support       0.98      0.95      0.97       154
#     Transactions & Payments       0.74      0.63      0.68       160
#
#                    accuracy                           0.89      2099
#                   macro avg       0.89      0.89      0.89      2099
#                weighted avg       0.89      0.89      0.89      2099
#
#
# Training model: LinearSVC
# Classification report for LinearSVC:
#
#                              precision    recall  f1-score   support
#
#             Account Details       0.85      0.94      0.89       143
#           Account Inquiries       0.96      0.94      0.95       142
#                Appointments       0.95      0.99      0.97       145
#                  Complaints       0.99      1.00      1.00       159
#           Debit/Credit Card       0.91      0.89      0.90       187
#            Fees and Charges       0.93      0.90      0.91       155
# Fraud and Security Concerns       0.96      0.98      0.97       151
#    General Financial Advice       0.97      0.99      0.98       157
#    Loan and Credit Services       0.83      0.84      0.84       137
#                 New Account       0.98      0.98      0.98       139
#           Product Inquiries       0.85      0.82      0.83       143
#                       Sales       0.84      0.90      0.87       127
#           Technical Support       0.99      0.99      0.99       154
#     Transactions & Payments       0.82      0.72      0.77       160
#
#                    accuracy                           0.92      2099
#                   macro avg       0.92      0.92      0.92      2099
#                weighted avg       0.92      0.92      0.92      2099
#
#
# Training model: LogisticRegression
# Classification report for LogisticRegression:
#
#                              precision    recall  f1-score   support
#
#             Account Details       0.86      0.92      0.89       143
#           Account Inquiries       0.93      0.89      0.91       142
#                Appointments       0.95      0.99      0.97       145
#                  Complaints       0.99      1.00      1.00       159
#           Debit/Credit Card       0.89      0.90      0.90       187
#            Fees and Charges       0.93      0.85      0.89       155
# Fraud and Security Concerns       0.97      0.98      0.98       151
#    General Financial Advice       0.97      0.99      0.98       157
#    Loan and Credit Services       0.83      0.89      0.86       137
#                 New Account       0.97      0.99      0.98       139
#           Product Inquiries       0.87      0.81      0.84       143
#                       Sales       0.86      0.89      0.87       127
#           Technical Support       0.99      0.97      0.98       154
#     Transactions & Payments       0.80      0.76      0.78       160
#
#                    accuracy                           0.92      2099
#                   macro avg       0.92      0.92      0.92      2099
#                weighted avg       0.92      0.92      0.92      2099
#
#
# Training model: RandomForest
# Classification report for RandomForest:
#
#                              precision    recall  f1-score   support
#
#             Account Details       0.63      0.70      0.66       143
#           Account Inquiries       0.76      0.73      0.75       142
#                Appointments       0.77      0.99      0.87       145
#                  Complaints       0.98      1.00      0.99       159
#           Debit/Credit Card       0.73      0.91      0.81       187
#            Fees and Charges       0.77      0.68      0.72       155
# Fraud and Security Concerns       0.91      0.87      0.89       151
#    General Financial Advice       0.89      0.99      0.94       157
#    Loan and Credit Services       0.74      0.88      0.81       137
#                 New Account       0.83      0.97      0.90       139
#           Product Inquiries       0.88      0.66      0.76       143
#                       Sales       0.72      0.68      0.70       127
#           Technical Support       0.93      0.89      0.91       154
#     Transactions & Payments       0.66      0.26      0.38       160
#
#                    accuracy                           0.80      2099
#                   macro avg       0.80      0.80      0.79      2099
#                weighted avg       0.80      0.80      0.79      2099
#
#
# Training model: HistGradientBoosting
# Classification report for HistGradientBoosting:
#
#                              precision    recall  f1-score   support
#
#             Account Details       0.83      0.80      0.81       143
#           Account Inquiries       0.83      0.82      0.82       142
#                Appointments       0.90      0.95      0.92       145
#                  Complaints       0.98      1.00      0.99       159
#           Debit/Credit Card       0.85      0.89      0.87       187
#            Fees and Charges       0.85      0.78      0.81       155
# Fraud and Security Concerns       0.91      0.91      0.91       151
#    General Financial Advice       0.94      0.97      0.96       157
#    Loan and Credit Services       0.82      0.91      0.87       137
#                 New Account       0.91      0.98      0.94       139
#           Product Inquiries       0.90      0.80      0.84       143
#                       Sales       0.76      0.81      0.79       127
#           Technical Support       0.93      0.94      0.94       154
#     Transactions & Payments       0.71      0.60      0.65       160
#
#                    accuracy                           0.87      2099
#                   macro avg       0.87      0.87      0.87      2099
#                weighted avg       0.87      0.87      0.87      2099

# %%
# Fit models and store confusion matrices
fig3, axes = plt.subplots(2, 3, figsize=(18, 10))  # Adjust based on number of models
axes = axes.flatten()

for idx, (name, model) in enumerate(models.items()):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred, labels=model.classes_ if hasattr(model, 'classes_') else sorted(set(y_train)))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_ if hasattr(model, 'classes_') else sorted(set(y_train)))
    disp.plot(ax=axes[idx], values_format='d', cmap='Blues')
    axes[idx].set_title(name)

# Hide any unused subplot axes
for i in range(len(models), len(axes)):
    fig3.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
import pandas as pd

# Store model accuracies
accuracy_data = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    accuracy_data.append({'Model': name, 'Accuracy': acc})

# Create DataFrame for display
accuracy_df = pd.DataFrame(accuracy_data)
accuracy_df = accuracy_df.sort_values(by='Accuracy', ascending=False).reset_index(drop=True)

print(accuracy_df)
# Out:
#                   Model  Accuracy
# 0             LinearSVC  0.919009
# 1    LogisticRegression  0.916151
# 2      SVC (RBF Kernel)  0.887566
# 3  HistGradientBoosting  0.868509
# 4          RandomForest  0.814674

# %%
import joblib

# %%
# Access the trained model
linearsvc_model = models["LinearSVC"]

# Export to file
joblib.dump(linearsvc_model, "linear_svc_model.pkl")
# Out:
# ['linear_svc_model.pkl']
